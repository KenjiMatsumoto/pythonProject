# %%
from numpy.random import randn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  5.,   6.,  14.,  10.,  19.,  16.,  15.,   4.,   6.,   5.]),
#  array([-2.06552278, -1.63184332, -1.19816385, -0.76448439, -0.33080493,
#          0.10287453,  0.536554  ,  0.97023346,  1.40391292,  1.83759238,
#          2.27127185]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([  2.,   1.,   1.,   9.,  18.,  12.,  20.,  10.,   4.,   3.]),
#  array([-3.23119929, -2.6623148 , -2.0934303 , -1.52454581, -0.95566131,
#         -0.38677682,  0.18210767,  0.75099217,  1.31987666,  1.88876116,
#          2.45764565]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True)
# Out:
# (array([ 0.11529252,  0.13835103,  0.32281907,  0.23058505,  0.43811159,
#          0.36893608,  0.34587757,  0.09223402,  0.13835103,  0.11529252]),
#  array([-2.06552278, -1.63184332, -1.19816385, -0.76448439, -0.33080493,
#          0.10287453,  0.536554  ,  0.97023346,  1.40391292,  1.83759238,
#          2.27127185]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,alpha=0.5,bins=20)
plt.hist(dataset2, normed=True,alpha=0.5,bins=20, color='indianred')
# Out:
# (array([ 0.04394565,  0.04394565,  0.        ,  0.04394565,  0.        ,
#          0.04394565,  0.21972826,  0.17578261,  0.21972826,  0.57129348,
#          0.30761956,  0.21972826,  0.39551087,  0.48340217,  0.26367391,
#          0.17578261,  0.0878913 ,  0.0878913 ,  0.04394565,  0.0878913 ]),
#  array([-3.23119929, -2.94675705, -2.6623148 , -2.37787255, -2.0934303 ,
#         -1.80898806, -1.52454581, -1.24010356, -0.95566131, -0.67121907,
#         -0.38677682, -0.10233457,  0.18210767,  0.46654992,  0.75099217,
#          1.03543442,  1.31987666,  1.60431891,  1.88876116,  2.17320341,
#          2.45764565]),
#  <a list of 20 Patch objects>)

# %%
data1= randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2, kind='hex')
