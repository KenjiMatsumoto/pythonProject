# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#                                                          Best win–loss record  \
# Rank Team         Won       Lost        Tied Pct. First   NFL   Season  Total
# 1    Dallas       Cowboys   502         374  6    .573   1960      882    NFC
# 2    Green        Bay       Packers     737  562  37     .565     1921  1,336
# 3    Chicago      Bears     749         579  42   .562   1920    1,370    NFC
# 4    Miami        Dolphins  445         351  4    .559   1966      800    AFC
# 5    New          England   Patriots[b] 489  386  9      .558     1960    884
# 6    Minnesota    Vikings   470         390  10   .546   1961      870    NFC
# 7    Baltimore    Ravens    190         161  1    .541   1996      352    AFC
# 8    New          York      Giants      687  585  33     .539     1925  1,305
# 9    Denver       Broncos   470         404  10   .537   1960      884    AFC
# 10   San          Francisco 49ers       528  460  14     .534     1950  1,002
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Best', 'win–loss', 'record', 'in', 'division'], dtype='object')

# %%
nfl_frame['Best']
# Out:
# Rank  Team          Won        Lost         Tied  Pct.  First     NFL
# 1     Dallas        Cowboys    502          374   6     .573     1960
# 2     Green         Bay        Packers      737   562   37       .565
# 3     Chicago       Bears      749          579   42    .562     1920
# 4     Miami         Dolphins   445          351   4     .559     1966
# 5     New           England    Patriots[b]  489   386   9        .558
# 6     Minnesota     Vikings    470          390   10    .546     1961
# 7     Baltimore     Ravens     190          161   1     .541     1996
# 8     New           York       Giants       687   585   33       .539
# 9     Denver        Broncos    470          404   10    .537     1960
# 10    San           Francisco  49ers        528   460   14       .534
# 11    Pittsburgh    Steelers   614          538   20    .532     1933
# 12    Oakland       Raiders    462          411   11    .529     1960
# ...

# %%
nfl_frame.Best
# Out:
# Rank  Team          Won        Lost         Tied  Pct.  First     NFL
# 1     Dallas        Cowboys    502          374   6     .573     1960
# 2     Green         Bay        Packers      737   562   37       .565
# 3     Chicago       Bears      749          579   42    .562     1920
# 4     Miami         Dolphins   445          351   4     .559     1966
# 5     New           England    Patriots[b]  489   386   9        .558
# 6     Minnesota     Vikings    470          390   10    .546     1961
# 7     Baltimore     Ravens     190          161   1     .541     1996
# 8     New           York       Giants       687   585   33       .539
# 9     Denver        Broncos    470          404   10    .537     1960
# 10    San           Francisco  49ers        528   460   14       .534
# 11    Pittsburgh    Steelers   614          538   20    .532     1933
# 12    Oakland       Raiders    462          411   11    .529     1960
# ...

# %%
nfl_frame[['Best','record']]
# Out:
#                                                          Best record
# Rank Team         Won       Lost        Tied Pct. First   NFL  Total
# 1    Dallas       Cowboys   502         374  6    .573   1960    NFC
# 2    Green        Bay       Packers     737  562  37     .565  1,336
# 3    Chicago      Bears     749         579  42   .562   1920    NFC
# 4    Miami        Dolphins  445         351  4    .559   1966    AFC
# 5    New          England   Patriots[b] 489  386  9      .558    884
# 6    Minnesota    Vikings   470         390  10   .546   1961    NFC
# 7    Baltimore    Ravens    190         161  1    .541   1996    AFC
# 8    New          York      Giants      687  585  33     .539  1,305
# 9    Denver       Broncos   470         404  10   .537   1960    AFC
# 10   San          Francisco 49ers       528  460  14     .534  1,002
# 11   Pittsburgh   Steelers  614         538  20   .532   1933    AFC
# 12   Oakland      Raiders   462         411  11   .529   1960    AFC
# ...

# %%
DataFrame(nfl_frame, columns= ['record', 'in'])
# Out:
#                                                         record     in
# Rank Team         Won       Lost        Tied Pct. First  Total  Games
# 1    Dallas       Cowboys   502         374  6    .573     NFC   East
# 2    Green        Bay       Packers     737  562  37     1,336    NFC
# 3    Chicago      Bears     749         579  42   .562     NFC  North
# 4    Miami        Dolphins  445         351  4    .559     AFC   East
# 5    New          England   Patriots[b] 489  386  9        884    AFC
# 6    Minnesota    Vikings   470         390  10   .546     NFC  North
# 7    Baltimore    Ravens    190         161  1    .541     AFC  North
# 8    New          York      Giants      687  585  33     1,305    NFC
# 9    Denver       Broncos   470         404  10   .537     AFC   West
# 10   San          Francisco 49ers       528  460  14     1,002    NFC
# 11   Pittsburgh   Steelers  614         538  20   .532     AFC  North
# ...

# %%
DataFrame(nfl_frame, columns= ['record', 'in', 'text'])
# Out:
#                                                         record     in  text
# Rank Team         Won       Lost        Tied Pct. First  Total  Games   NaN
# 1    Dallas       Cowboys   502         374  6    .573     NFC   East   NaN
# 2    Green        Bay       Packers     737  562  37     1,336    NFC   NaN
# 3    Chicago      Bears     749         579  42   .562     NFC  North   NaN
# 4    Miami        Dolphins  445         351  4    .559     AFC   East   NaN
# 5    New          England   Patriots[b] 489  386  9        884    AFC   NaN
# 6    Minnesota    Vikings   470         390  10   .546     NFC  North   NaN
# 7    Baltimore    Ravens    190         161  1    .541     AFC  North   NaN
# 8    New          York      Giants      687  585  33     1,305    NFC   NaN
# 9    Denver       Broncos   470         404  10   .537     AFC   West   NaN
# 10   San          Francisco 49ers       528  460  14     1,002    NFC   NaN
# ...

# %%
nfl_frame.head()
# Out:
#                                                Best win–loss record     in  \
# Rank Team    Won      Lost    Tied Pct. First   NFL   Season  Total  Games
# 1    Dallas  Cowboys  502     374  6    .573   1960      882    NFC   East
# 2    Green   Bay      Packers 737  562  37     .565     1921  1,336    NFC
# 3    Chicago Bears    749     579  42   .562   1920    1,370    NFC  North
# 4    Miami   Dolphins 445     351  4    .559   1966      800    AFC   East
#
#                                                division
# Rank Team    Won      Lost    Tied Pct. First  Division
# 1    Dallas  Cowboys  502     374  6    .573        NaN
# 2    Green   Bay      Packers 737  562  37        North
# 3    Chicago Bears    749     579  42   .562        NaN
# 4    Miami   Dolphins 445     351  4    .559        NaN

# %%
nfl_frame.head(3)
# Out:
#                                              Best win–loss record     in  \
# Rank Team   Won     Lost    Tied Pct. First   NFL   Season  Total  Games
# 1    Dallas Cowboys 502     374  6    .573   1960      882    NFC   East
# 2    Green  Bay     Packers 737  562  37     .565     1921  1,336    NFC
#
#                                              division
# Rank Team   Won     Lost    Tied Pct. First  Division
# 1    Dallas Cowboys 502     374  6    .573        NaN
# 2    Green  Bay     Packers 737  562  37        North

# %%
nfl_frame.tail(3)
# Out:
#                                           Best win–loss record     in division
# 11 Pittsburgh   Steelers 614 538 20 .532  1933    1,172    AFC  North      NaN
# 12 Oakland      Raiders  462 411 11 .529  1960      884    AFC   West      NaN
# 13 Indianapolis Colts[c] 506 453 7  .527  1953      966    AFC  South      NaN

# %%
nfl_frame.ix[3]
# Out:
# Best         1920
# win–loss    1,370
# record        NFC
# in          North
# division      NaN
# Name: (3, Chicago, Bears, 749, 579, 42, .562), dtype: object

# %%
nfl_frame['record'] = 'text'

# %%
nfl_frame
# Out:
#                                                          Best win–loss record  \
# Rank Team         Won       Lost        Tied Pct. First   NFL   Season   text
# 1    Dallas       Cowboys   502         374  6    .573   1960      882   text
# 2    Green        Bay       Packers     737  562  37     .565     1921   text
# 3    Chicago      Bears     749         579  42   .562   1920    1,370   text
# 4    Miami        Dolphins  445         351  4    .559   1966      800   text
# 5    New          England   Patriots[b] 489  386  9      .558     1960   text
# 6    Minnesota    Vikings   470         390  10   .546   1961      870   text
# 7    Baltimore    Ravens    190         161  1    .541   1996      352   text
# 8    New          York      Giants      687  585  33     .539     1925   text
# 9    Denver       Broncos   470         404  10   .537   1960      884   text
# 10   San          Francisco 49ers       528  460  14     .534     1950   text
# ...

# %%
nfl_frame['records'] = 'test2'

# %%
nfl_frame
# Out:
#                                                          Best win–loss record  \
# Rank Team         Won       Lost        Tied Pct. First   NFL   Season   text
# 1    Dallas       Cowboys   502         374  6    .573   1960      882   text
# 2    Green        Bay       Packers     737  562  37     .565     1921   text
# 3    Chicago      Bears     749         579  42   .562   1920    1,370   text
# 4    Miami        Dolphins  445         351  4    .559   1966      800   text
# 5    New          England   Patriots[b] 489  386  9      .558     1960   text
# 6    Minnesota    Vikings   470         390  10   .546   1961      870   text
# 7    Baltimore    Ravens    190         161  1    .541   1996      352   text
# 8    New          York      Giants      687  585  33     .539     1925   text
# 9    Denver       Broncos   470         404  10   .537   1960      884   text
# 10   San          Francisco 49ers       528  460  14     .534     1950   text
# ...

# %%
nfl_frame['records'] = 'test'

# %%
nfl_frame
# Out:
#                                                          Best win–loss record  \
# Rank Team         Won       Lost        Tied Pct. First   NFL   Season   text
# 1    Dallas       Cowboys   502         374  6    .573   1960      882   text
# 2    Green        Bay       Packers     737  562  37     .565     1921   text
# 3    Chicago      Bears     749         579  42   .562   1920    1,370   text
# 4    Miami        Dolphins  445         351  4    .559   1966      800   text
# 5    New          England   Patriots[b] 489  386  9      .558     1960   text
# 6    Minnesota    Vikings   470         390  10   .546   1961      870   text
# 7    Baltimore    Ravens    190         161  1    .541   1996      352   text
# 8    New          York      Giants      687  585  33     .539     1925   text
# 9    Denver       Broncos   470         404  10   .537   1960      884   text
# 10   San          Francisco 49ers       528  460  14     .534     1950   text
# ...

# %%
nfl_frame['records'] = np.arange(12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8b85412fc18b> in <module>()
# ----> 1 nfl_frame['records'] = np.arange(12)
#
# ~/.pyenv/versions/3.6.2/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/.pyenv/versions/3.6.2/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~/.pyenv/versions/3.6.2/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
del nfl_frame['records']

# %%
nfl_frame
# Out:
#                                                          Best win–loss record  \
# Rank Team         Won       Lost        Tied Pct. First   NFL   Season   text
# 1    Dallas       Cowboys   502         374  6    .573   1960      882   text
# 2    Green        Bay       Packers     737  562  37     .565     1921   text
# 3    Chicago      Bears     749         579  42   .562   1920    1,370   text
# 4    Miami        Dolphins  445         351  4    .559   1966      800   text
# 5    New          England   Patriots[b] 489  386  9      .558     1960   text
# 6    Minnesota    Vikings   470         390  10   .546   1961      870   text
# 7    Baltimore    Ravens    190         161  1    .541   1996      352   text
# 8    New          York      Giants      687  585  33     .539     1925   text
# 9    Denver       Broncos   470         404  10   .537   1960      884   text
# 10   San          Francisco 49ers       528  460  14     .534     1950   text
# ...

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000,3880000,8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
